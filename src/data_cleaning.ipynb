# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('/Users/nittarin/Downloads/VSCode/graspp-25S-innovation/data/2023_kaku_01-10.xls')

# %%
df
# Out:
#     第１巻　〔研究開発に関する表〕第１０表  産業別、企業数、売上高、研究開発費及び売上高比率、受託研究費、研究開発投資、能力開発費\n  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 168                                                927
# 169                                                928
# 170                                                929
# 171                                                 R2
# 172                                                  Z
#
#            Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0                 NaN         NaN      列見出し1       研究開発       研究開発       研究開発
# 1                 NaN         NaN      列見出し2        企業数        売上高      研究開発費
# ...
